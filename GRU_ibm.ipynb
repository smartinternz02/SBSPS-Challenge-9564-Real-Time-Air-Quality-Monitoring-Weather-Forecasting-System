# %%
import pandas as pd
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import GRU

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
station_day = pd.read_csv("/content/station_day.csv")

# %%
sd=pd.DataFrame(station_day)

# %%
sd=pd.DataFrame(station_day)

# %%
sd["Date"]= pd.to_datetime(sd["Date"])

# %%
sd.drop(['AQI_Bucket', 'StationId'], axis=1, inplace=True)

# %%
sd=sd.dropna()

# %%
sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10314 entries, 1 to 106147
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     10314 non-null  datetime64[ns]
#  1   PM2.5    10314 non-null  float64
#  2   PM10     10314 non-null  float64
#  3   NO       10314 non-null  float64
#  4   NO2      10314 non-null  float64
#  5   NOx      10314 non-null  float64
#  6   NH3      10314 non-null  float64
#  7   CO       10314 non-null  float64
#  8   SO2      10314 non-null  float64
#  9   O3       10314 non-null  float64
#  10  Benzene  10314 non-null  float64
#  11  Toluene  10314 non-null  float64
#  12  Xylene   10314 non-null  float64
#  13  AQI      10314 non-null  float64
# dtypes: datetime64[ns](1), float64(13)
# memory usage: 1.2 MB

# %%
dates = sd['Date']
sd.drop('Date', axis=1,inplace=True) 
sd.head()
values = sd.values

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
scaled = scaler.fit_transform(values)

# %%
n_days = 7
n_features = 13
reframed = series_to_supervised(scaled, n_days, 1)

# %%
values = reframed.values 
reframed.head()
# Out:
#     var1(t-7)  var2(t-7)  var3(t-7)  var4(t-7)  var5(t-7)  var6(t-7)  \
# 7    0.109493   0.144032   0.005420   0.080425   0.036382   0.039358
# 8    0.105294   0.149564   0.004733   0.102014   0.044739   0.037727
# 9    0.119528   0.157158   0.025116   0.121050   0.065615   0.047474
# 10   0.086016   0.119273   0.009695   0.110139   0.051255   0.041952
# 11   0.097318   0.132314   0.019887   0.091023   0.049988   0.045028
#
#     var7(t-7)  var8(t-7)  var9(t-7)  var10(t-7)  ...   var4(t)   var5(t)  \
# 7    0.025316   0.225432   0.782871    0.001209  ...  0.102759  0.059883
# 8    0.029536   0.399940   0.723413    0.001330  ...  0.083605  0.036503
# 9    0.023207   0.498660   0.688725    0.001753  ...  0.105860  0.052975
# 10   0.018987   0.281418   0.851201    0.001028  ...  0.079366  0.041420
# 11   0.033755   0.155599   0.675970    0.001270  ...  0.100640  0.045161
#
#      var6(t)   var7(t)   var8(t)   var9(t)  var10(t)  var11(t)  var12(t)  \
# 7   0.048253  0.021097  0.286927  0.792976  0.001511  0.010771  0.000524
# 8   0.052848  0.031646  0.168404  0.707147  0.001390  0.014747  0.000299
# 9   0.053033  0.037975  0.145027  0.692421  0.001874  0.013628  0.000674
# 10  0.050476  0.025316  0.207266  0.726433  0.001451  0.011273  0.000225
# 11  0.055665  0.023207  0.244789  0.721996  0.001753  0.017179  0.000524
#
#     var13(t)
# 7   0.258876
# 8   0.312130
# 9   0.224852
# 10  0.269231
# 11  0.273669
#
# [5 rows x 104 columns]

# %%
# train = values[:n_train_hours, :]
# test = values[n_train_hours:, :]

# %%
values = reframed.values 
# len(values)
#80:10:10
# 6188
# 2062
# 2062 
n_train_days = 8251
train = values[:n_train_days, :] 
val = values[n_train_days:1028+n_train_days,:]  
test=values[1028+n_train_days:,:]

# test
len(train) 
print(train.shape,val.shape,test.shape)
print(train.shape[0]+val.shape[0]+test.shape[0])
# Out:
# (8251, 104) (1028, 104) (1028, 104)
# 10307

# %%
n_obs = n_days* n_features
print(n_obs)
# Out:
# 91

# %%
train_X, train_y = train[:, :n_obs], train[:, -n_features]

val_X, val_y = val[:, :n_obs], val[:, -n_features]
test_X, test_y = test[:, :n_obs], test[:, -n_features]

# %%
train_X = train_X.reshape((train_X.shape[0], n_days, n_features))
val_X = val_X.reshape((val_X.shape[0],n_days,n_features))
test_X = test_X.reshape((test_X.shape[0], n_days, n_features))

# %%
from keras.callbacks import EarlyStopping
from keras.layers import Bidirectional,Embedding,GRU,Dropout
import numpy as np 

def test_diff_strategies(units,loss_tmp,optmzr,val_X,val_y,test_X,test_y):

  model_lstm = Sequential()
  model_lstm.add(GRU(90, input_shape=(train_X.shape[1], train_X.shape[2])))
  model_lstm.add(Dropout(0.2))
  model_lstm.add(Dense(1))
  # model_lstm = Sequential()
  # model_lstm.add(LSTM(units,input_shape=(train_X.shape[1], train_X.shape[2]),return_sequences=True))
  # model_lstm.add(Dropout(0.25))
  # # model_lstm.add(Dense(34 ,'relu'))
  # # model_lstm.add(Dropout(0.25))
  # model_lstm.add(LSTM(units))
  # model_lstm.add(Dropout(0.25))
  # # model_lstm.add(Dense(15 ,'relu'))

  # model_lstm.add(Dense(1 ,'relu' ))
  model_lstm.compile(loss=loss_tmp, optimizer=optmzr)
  es=EarlyStopping(monitor='val_loss',patience=30,verbose =1)
  history = model_lstm.fit(train_X, train_y, epochs=250,batch_size=32,callbacks=es,validation_data=(val_X, val_y), verbose=2, shuffle=False)
  model_lstm.reset_states()
  pyplot.plot(history.history['loss'], label='train')
  pyplot.plot(history.history['val_loss'], label='val')
  pyplot.legend() 
  pyplot.show()

  yhat = model_lstm.predict(val_X) 
  # print(len(yhat))
  fcp1=np.repeat(yhat,13,axis=1)
  # print(len(fcp1))
  inv_yhat=scaler.inverse_transform(fcp1)
  inv_yhat = inv_yhat[:,0]
  # print(inv_yhat)
  val_y = val_y.reshape((len(val_y), 1)) 
  # inv_y = concatenate((val_y, val_X[:, 1:]), axis=1)
  # print(inv_yhat)  
  fcp2=np.repeat(val_y,13,axis=1)
  inv_y = scaler.inverse_transform(fcp2) 
  inv_y = inv_y[:,0]
    
  validation_rmse = sqrt(mean_squared_error(inv_y, inv_yhat)) 
  yhat_test = model_lstm.predict(test_X)
  # test_X = test_X.reshape((test_X.shape[0], n_days*n_features))
  # # test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
  # inv_yhat_test = concatenate((yhat_test,test_X[:, 1:]), axis=1)
  fcp3=np.repeat(yhat_test,13,axis=1)
  inv_yhat_test = scaler.inverse_transform(fcp3) 
  # inv_yhat_test = scaler.inverse_transform(yhat_test)
  inv_yhat_test = inv_yhat_test[:,0]

  inv_yhat_test.reshape(inv_yhat_test.shape[0],1)

  test_y = test_y.reshape((len(test_y), 1))
  # inv_testy = concatenate((test_y, test_X[:, 1:]), axis=1) 
  fcp4=np.repeat(test_y,13,axis=1)
  inv_testy = scaler.inverse_transform(fcp4) 
  # inv_testy = scaler.inverse_transform(test_Y)
  inv_testy = inv_testy[:,0]

  inv_testy.reshape(inv_testy.shape[0],1)
  test_rmse=sqrt(mean_squared_error(inv_testy, inv_yhat_test))
  # epoch_list_temp=[]
  # batch_list_temp=[] 
  # validationrmse_list=[] 
  # testrmse_list=[]

  dict_of_values={'units':units,'optimizer':optmzr,'Loss':loss_tmp,'ValRMSE':validation_rmse,'TestRMSE':test_rmse}
  print(dict_of_values)
  return (dict_of_values,model_lstm,history)

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import * 
from tensorflow.keras.losses import *
list_of_results=[]
# list_of_units = [6,7,90,30,128] 

list_of_units=[30] 

# list_of_losses = [MeanSquaredLogarithmicError(),Huber(),LogCosh(),'mae','mse']

list_of_losses=['mse'] 
# list_of_optmzrs=[ Adam(),SGD(),RMSprop(),Adadelta(),Adagrad(),Adamax(),Nadam(),Ftrl()]
list_of_optmzrs=[Adamax(learning_rate=0.0003)]#$,Nadam(learning_rate=0.0003),Adam(learning_rate=0.0003)]

for unit in list_of_units:
  for loss in list_of_losses:
    for op in list_of_optmzrs: 
      dict_to_be_stored,model,his=test_diff_strategies(unit,loss,op,val_X,val_y,test_X,test_y) 
      list_of_results.append(dict_to_be_stored)
# Out:
# Epoch 1/250
# 258/258 - 3s - loss: 0.0078 - val_loss: 0.0015 - 3s/epoch - 10ms/step
# Epoch 2/250
# 258/258 - 1s - loss: 0.0051 - val_loss: 0.0013 - 956ms/epoch - 4ms/step
# Epoch 3/250
# 258/258 - 1s - loss: 0.0045 - val_loss: 0.0012 - 945ms/epoch - 4ms/step
# Epoch 4/250
# 258/258 - 1s - loss: 0.0041 - val_loss: 0.0011 - 873ms/epoch - 3ms/step
# Epoch 5/250
# 258/258 - 1s - loss: 0.0035 - val_loss: 9.6032e-04 - 957ms/epoch - 4ms/step
# Epoch 6/250
# 258/258 - 1s - loss: 0.0033 - val_loss: 8.6503e-04 - 877ms/epoch - 3ms/step
# Epoch 7/250
# 258/258 - 1s - loss: 0.0029 - val_loss: 7.6533e-04 - 937ms/epoch - 4ms/step
# Epoch 8/250
# 258/258 - 1s - loss: 0.0027 - val_loss: 6.9788e-04 - 865ms/epoch - 3ms/step
# Epoch 9/250
# 258/258 - 1s - loss: 0.0025 - val_loss: 6.2341e-04 - 954ms/epoch - 4ms/step
# Epoch 10/250
# 258/258 - 1s - loss: 0.0023 - val_loss: 5.6632e-04 - 952ms/epoch - 4ms/step
# Epoch 11/250
# 258/258 - 1s - loss: 0.0021 - val_loss: 5.1710e-04 - 870ms/epoch - 3ms/step
# Epoch 12/250
# 258/258 - 1s - loss: 0.0020 - val_loss: 4.7827e-04 - 947ms/epoch - 4ms/step
# Epoch 13/250
# 258/258 - 1s - loss: 0.0019 - val_loss: 4.3366e-04 - 877ms/epoch - 3ms/step
# Epoch 14/250
# 258/258 - 1s - loss: 0.0019 - val_loss: 4.0995e-04 - 952ms/epoch - 4ms/step
# Epoch 15/250
# 258/258 - 1s - loss: 0.0018 - val_loss: 3.8861e-04 - 972ms/epoch - 4ms/step
# Epoch 16/250
# 258/258 - 1s - loss: 0.0017 - val_loss: 3.7169e-04 - 901ms/epoch - 3ms/step
# Epoch 17/250
# 258/258 - 1s - loss: 0.0016 - val_loss: 3.6110e-04 - 881ms/epoch - 3ms/step
# Epoch 18/250
# 258/258 - 1s - loss: 0.0017 - val_loss: 3.5041e-04 - 858ms/epoch - 3ms/step
# Epoch 19/250
# 258/258 - 1s - loss: 0.0016 - val_loss: 3.4418e-04 - 960ms/epoch - 4ms/step
# Epoch 20/250
# 258/258 - 1s - loss: 0.0016 - val_loss: 3.3494e-04 - 879ms/epoch - 3ms/step
# Epoch 21/250
# 258/258 - 1s - loss: 0.0016 - val_loss: 3.2850e-04 - 875ms/epoch - 3ms/step
# Epoch 22/250
# 258/258 - 1s - loss: 0.0016 - val_loss: 3.2605e-04 - 899ms/epoch - 3ms/step
# Epoch 23/250
# 258/258 - 1s - loss: 0.0015 - val_loss: 3.1917e-04 - 874ms/epoch - 3ms/step
# Epoch 24/250
# 258/258 - 1s - loss: 0.0015 - val_loss: 3.1418e-04 - 873ms/epoch - 3ms/step
# Epoch 25/250
# 258/258 - 1s - loss: 0.0015 - val_loss: 3.1280e-04 - 946ms/epoch - 4ms/step
# Epoch 26/250
# 258/258 - 1s - loss: 0.0014 - val_loss: 3.0622e-04 - 952ms/epoch - 4ms/step
# Epoch 27/250
# 258/258 - 1s - loss: 0.0015 - val_loss: 3.0180e-04 - 1s/epoch - 4ms/step
# Epoch 28/250
# 258/258 - 1s - loss: 0.0015 - val_loss: 3.0168e-04 - 1s/epoch - 6ms/step
# Epoch 29/250
# 258/258 - 2s - loss: 0.0015 - val_loss: 2.9894e-04 - 2s/epoch - 6ms/step
# Epoch 30/250
# 258/258 - 2s - loss: 0.0014 - val_loss: 2.9507e-04 - 2s/epoch - 6ms/step
# Epoch 31/250
# 258/258 - 1s - loss: 0.0014 - val_loss: 2.9300e-04 - 1s/epoch - 5ms/step
# Epoch 32/250
# 258/258 - 2s - loss: 0.0014 - val_loss: 2.9208e-04 - 2s/epoch - 6ms/step
# Epoch 33/250
# 258/258 - 1s - loss: 0.0014 - val_loss: 2.8951e-04 - 1s/epoch - 5ms/step
# Epoch 34/250
# 258/258 - 1s - loss: 0.0014 - val_loss: 2.8654e-04 - 951ms/epoch - 4ms/step
# Epoch 35/250
# 258/258 - 1s - loss: 0.0014 - val_loss: 2.8526e-04 - 891ms/epoch - 3ms/step
# Epoch 36/250
# 258/258 - 1s - loss: 0.0013 - val_loss: 2.8219e-04 - 892ms/epoch - 3ms/step
# Epoch 37/250
# 258/258 - 1s - loss: 0.0013 - val_loss: 2.7915e-04 - 893ms/epoch - 3ms/step
# Epoch 38/250
# 258/258 - 1s - loss: 0.0013 - val_loss: 2.7868e-04 - 880ms/epoch - 3ms/step
# Epoch 39/250
# 258/258 - 1s - loss: 0.0014 - val_loss: 2.7616e-04 - 861ms/epoch - 3ms/step
# Epoch 40/250
# 258/258 - 1s - loss: 0.0013 - val_loss: 2.7536e-04 - 879ms/epoch - 3ms/step
# Epoch 41/250
# 258/258 - 1s - loss: 0.0013 - val_loss: 2.7402e-04 - 903ms/epoch - 4ms/step
# Epoch 42/250
# 258/258 - 1s - loss: 0.0014 - val_loss: 2.7334e-04 - 874ms/epoch - 3ms/step
# Epoch 43/250
# 258/258 - 1s - loss: 0.0013 - val_loss: 2.7129e-04 - 977ms/epoch - 4ms/step
# Epoch 44/250
# 258/258 - 1s - loss: 0.0013 - val_loss: 2.6995e-04 - 877ms/epoch - 3ms/step
# Epoch 45/250
# 258/258 - 1s - loss: 0.0013 - val_loss: 2.6878e-04 - 950ms/epoch - 4ms/step
# Epoch 46/250
# 258/258 - 1s - loss: 0.0013 - val_loss: 2.6638e-04 - 886ms/epoch - 3ms/step
# Epoch 47/250
# 258/258 - 1s - loss: 0.0013 - val_loss: 2.6604e-04 - 885ms/epoch - 3ms/step
# Epoch 48/250
# 258/258 - 1s - loss: 0.0013 - val_loss: 2.6655e-04 - 847ms/epoch - 3ms/step
# Epoch 49/250
# 258/258 - 1s - loss: 0.0013 - val_loss: 2.6350e-04 - 949ms/epoch - 4ms/step
# Epoch 50/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.6278e-04 - 900ms/epoch - 3ms/step
# Epoch 51/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.6179e-04 - 871ms/epoch - 3ms/step
# Epoch 52/250
# 258/258 - 1s - loss: 0.0013 - val_loss: 2.6111e-04 - 867ms/epoch - 3ms/step
# Epoch 53/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.5906e-04 - 862ms/epoch - 3ms/step
# Epoch 54/250
# 258/258 - 1s - loss: 0.0013 - val_loss: 2.5845e-04 - 890ms/epoch - 3ms/step
# Epoch 55/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.5759e-04 - 874ms/epoch - 3ms/step
# Epoch 56/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.5735e-04 - 868ms/epoch - 3ms/step
# Epoch 57/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.5674e-04 - 882ms/epoch - 3ms/step
# Epoch 58/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.5674e-04 - 876ms/epoch - 3ms/step
# Epoch 59/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.5625e-04 - 877ms/epoch - 3ms/step
# Epoch 60/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.5378e-04 - 1s/epoch - 4ms/step
# Epoch 61/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.5397e-04 - 1s/epoch - 4ms/step
# Epoch 62/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.5156e-04 - 1s/epoch - 6ms/step
# Epoch 63/250
# 258/258 - 2s - loss: 0.0012 - val_loss: 2.5202e-04 - 2s/epoch - 6ms/step
# Epoch 64/250
# 258/258 - 2s - loss: 0.0012 - val_loss: 2.5106e-04 - 2s/epoch - 6ms/step
# Epoch 65/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.5378e-04 - 1s/epoch - 5ms/step
# Epoch 66/250
# 258/258 - 2s - loss: 0.0012 - val_loss: 2.5316e-04 - 2s/epoch - 7ms/step
# Epoch 67/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.4805e-04 - 1s/epoch - 5ms/step
# Epoch 68/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.4962e-04 - 1s/epoch - 5ms/step
# Epoch 69/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.4872e-04 - 1s/epoch - 4ms/step
# Epoch 70/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.4728e-04 - 856ms/epoch - 3ms/step
# Epoch 71/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.4616e-04 - 867ms/epoch - 3ms/step
# Epoch 72/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.4598e-04 - 871ms/epoch - 3ms/step
# Epoch 73/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.4484e-04 - 892ms/epoch - 3ms/step
# Epoch 74/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.4498e-04 - 982ms/epoch - 4ms/step
# Epoch 75/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.4847e-04 - 894ms/epoch - 3ms/step
# Epoch 76/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.4474e-04 - 871ms/epoch - 3ms/step
# Epoch 77/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.4613e-04 - 884ms/epoch - 3ms/step
# Epoch 78/250
# 258/258 - 1s - loss: 0.0012 - val_loss: 2.4221e-04 - 856ms/epoch - 3ms/step
# Epoch 79/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.4445e-04 - 890ms/epoch - 3ms/step
# Epoch 80/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.4244e-04 - 874ms/epoch - 3ms/step
# Epoch 81/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.4182e-04 - 864ms/epoch - 3ms/step
# Epoch 82/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.4019e-04 - 956ms/epoch - 4ms/step
# Epoch 83/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.4076e-04 - 876ms/epoch - 3ms/step
# Epoch 84/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.4038e-04 - 875ms/epoch - 3ms/step
# Epoch 85/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.3974e-04 - 891ms/epoch - 3ms/step
# Epoch 86/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.4170e-04 - 875ms/epoch - 3ms/step
# Epoch 87/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.3655e-04 - 885ms/epoch - 3ms/step
# Epoch 88/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.3820e-04 - 866ms/epoch - 3ms/step
# Epoch 89/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.3766e-04 - 863ms/epoch - 3ms/step
# Epoch 90/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.3648e-04 - 867ms/epoch - 3ms/step
# Epoch 91/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.3511e-04 - 949ms/epoch - 4ms/step
# Epoch 92/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.3525e-04 - 867ms/epoch - 3ms/step
# Epoch 93/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.3612e-04 - 936ms/epoch - 4ms/step
# Epoch 94/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.3806e-04 - 946ms/epoch - 4ms/step
# Epoch 95/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.3428e-04 - 1s/epoch - 6ms/step
# Epoch 96/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.3393e-04 - 1s/epoch - 6ms/step
# Epoch 97/250
# 258/258 - 2s - loss: 0.0011 - val_loss: 2.3452e-04 - 2s/epoch - 6ms/step
# Epoch 98/250
# 258/258 - 2s - loss: 0.0011 - val_loss: 2.3304e-04 - 2s/epoch - 6ms/step
# Epoch 99/250
# 258/258 - 2s - loss: 0.0011 - val_loss: 2.3254e-04 - 2s/epoch - 6ms/step
# Epoch 100/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.3207e-04 - 1s/epoch - 4ms/step
# Epoch 101/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.3210e-04 - 958ms/epoch - 4ms/step
# Epoch 102/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.3245e-04 - 908ms/epoch - 4ms/step
# Epoch 103/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.3047e-04 - 941ms/epoch - 4ms/step
# Epoch 104/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.2906e-04 - 965ms/epoch - 4ms/step
# Epoch 105/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.3281e-04 - 890ms/epoch - 3ms/step
# Epoch 106/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.2932e-04 - 877ms/epoch - 3ms/step
# Epoch 107/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.2975e-04 - 911ms/epoch - 4ms/step
# Epoch 108/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.2806e-04 - 894ms/epoch - 3ms/step
# Epoch 109/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.2685e-04 - 889ms/epoch - 3ms/step
# Epoch 110/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.3411e-04 - 895ms/epoch - 3ms/step
# Epoch 111/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.3059e-04 - 950ms/epoch - 4ms/step
# Epoch 112/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.2704e-04 - 885ms/epoch - 3ms/step
# Epoch 113/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.2838e-04 - 959ms/epoch - 4ms/step
# Epoch 114/250
# 258/258 - 1s - loss: 0.0011 - val_loss: 2.2765e-04 - 952ms/epoch - 4ms/step
# Epoch 115/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.2650e-04 - 895ms/epoch - 3ms/step
# Epoch 116/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.2460e-04 - 899ms/epoch - 3ms/step
# Epoch 117/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.2645e-04 - 888ms/epoch - 3ms/step
# Epoch 118/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.2330e-04 - 878ms/epoch - 3ms/step
# Epoch 119/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.2340e-04 - 979ms/epoch - 4ms/step
# Epoch 120/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.2232e-04 - 1s/epoch - 5ms/step
# Epoch 121/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.2470e-04 - 1s/epoch - 5ms/step
# Epoch 122/250
# 258/258 - 1s - loss: 9.9715e-04 - val_loss: 2.2281e-04 - 924ms/epoch - 4ms/step
# Epoch 123/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.2313e-04 - 949ms/epoch - 4ms/step
# Epoch 124/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.2481e-04 - 875ms/epoch - 3ms/step
# Epoch 125/250
# 258/258 - 1s - loss: 9.9563e-04 - val_loss: 2.2116e-04 - 963ms/epoch - 4ms/step
# Epoch 126/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.2148e-04 - 969ms/epoch - 4ms/step
# Epoch 127/250
# 258/258 - 1s - loss: 9.9804e-04 - val_loss: 2.2290e-04 - 1s/epoch - 5ms/step
# Epoch 128/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.2076e-04 - 1s/epoch - 6ms/step
# Epoch 129/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.2314e-04 - 1s/epoch - 6ms/step
# Epoch 130/250
# 258/258 - 2s - loss: 0.0010 - val_loss: 2.2005e-04 - 2s/epoch - 6ms/step
# Epoch 131/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.1892e-04 - 1s/epoch - 5ms/step
# Epoch 132/250
# 258/258 - 2s - loss: 0.0010 - val_loss: 2.2051e-04 - 2s/epoch - 6ms/step
# Epoch 133/250
# 258/258 - 1s - loss: 9.9355e-04 - val_loss: 2.2141e-04 - 960ms/epoch - 4ms/step
# Epoch 134/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.1682e-04 - 874ms/epoch - 3ms/step
# Epoch 135/250
# 258/258 - 1s - loss: 9.8258e-04 - val_loss: 2.1879e-04 - 897ms/epoch - 3ms/step
# Epoch 136/250
# 258/258 - 1s - loss: 9.9753e-04 - val_loss: 2.1764e-04 - 911ms/epoch - 4ms/step
# Epoch 137/250
# 258/258 - 1s - loss: 9.7373e-04 - val_loss: 2.1788e-04 - 909ms/epoch - 4ms/step
# Epoch 138/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.1775e-04 - 880ms/epoch - 3ms/step
# Epoch 139/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.1682e-04 - 956ms/epoch - 4ms/step
# Epoch 140/250
# 258/258 - 1s - loss: 0.0010 - val_loss: 2.1388e-04 - 944ms/epoch - 4ms/step
# Epoch 141/250
# 258/258 - 1s - loss: 9.5551e-04 - val_loss: 2.1357e-04 - 876ms/epoch - 3ms/step
# Epoch 142/250
# 258/258 - 1s - loss: 9.8144e-04 - val_loss: 2.1694e-04 - 871ms/epoch - 3ms/step
# Epoch 143/250
# 258/258 - 1s - loss: 9.9573e-04 - val_loss: 2.1428e-04 - 887ms/epoch - 3ms/step
# Epoch 144/250
# 258/258 - 1s - loss: 9.6829e-04 - val_loss: 2.1395e-04 - 881ms/epoch - 3ms/step
# Epoch 145/250
# 258/258 - 1s - loss: 9.8691e-04 - val_loss: 2.1618e-04 - 882ms/epoch - 3ms/step
# Epoch 146/250
# 258/258 - 1s - loss: 9.6202e-04 - val_loss: 2.1341e-04 - 886ms/epoch - 3ms/step
# Epoch 147/250
# 258/258 - 1s - loss: 9.9416e-04 - val_loss: 2.1119e-04 - 885ms/epoch - 3ms/step
# Epoch 148/250
# 258/258 - 1s - loss: 9.6487e-04 - val_loss: 2.1604e-04 - 977ms/epoch - 4ms/step
# Epoch 149/250
# 258/258 - 1s - loss: 9.8245e-04 - val_loss: 2.1425e-04 - 870ms/epoch - 3ms/step
# Epoch 150/250
# 258/258 - 1s - loss: 9.7026e-04 - val_loss: 2.1235e-04 - 864ms/epoch - 3ms/step
# Epoch 151/250
# 258/258 - 1s - loss: 9.5251e-04 - val_loss: 2.1013e-04 - 871ms/epoch - 3ms/step
# Epoch 152/250
# 258/258 - 1s - loss: 9.7007e-04 - val_loss: 2.1213e-04 - 870ms/epoch - 3ms/step
# Epoch 153/250
# 258/258 - 1s - loss: 9.7999e-04 - val_loss: 2.1097e-04 - 890ms/epoch - 3ms/step
# Epoch 154/250
# 258/258 - 1s - loss: 9.8426e-04 - val_loss: 2.1256e-04 - 896ms/epoch - 3ms/step
# Epoch 155/250
# 258/258 - 1s - loss: 9.7856e-04 - val_loss: 2.1107e-04 - 883ms/epoch - 3ms/step
# Epoch 156/250
# 258/258 - 1s - loss: 9.9070e-04 - val_loss: 2.1040e-04 - 890ms/epoch - 3ms/step
# Epoch 157/250
# 258/258 - 1s - loss: 9.7011e-04 - val_loss: 2.1022e-04 - 877ms/epoch - 3ms/step
# Epoch 158/250
# 258/258 - 1s - loss: 9.7096e-04 - val_loss: 2.0781e-04 - 958ms/epoch - 4ms/step
# Epoch 159/250
# 258/258 - 1s - loss: 9.7894e-04 - val_loss: 2.0942e-04 - 1s/epoch - 4ms/step
# Epoch 160/250
# 258/258 - 1s - loss: 9.7639e-04 - val_loss: 2.0618e-04 - 1s/epoch - 4ms/step
# Epoch 161/250
# 258/258 - 2s - loss: 9.7406e-04 - val_loss: 2.0984e-04 - 2s/epoch - 6ms/step
# Epoch 162/250
# 258/258 - 2s - loss: 9.5214e-04 - val_loss: 2.0608e-04 - 2s/epoch - 6ms/step
# Epoch 163/250
# 258/258 - 2s - loss: 9.5113e-04 - val_loss: 2.1026e-04 - 2s/epoch - 7ms/step
# Epoch 164/250
# 258/258 - 1s - loss: 9.5568e-04 - val_loss: 2.0811e-04 - 1s/epoch - 5ms/step
# Epoch 165/250
# 258/258 - 1s - loss: 9.6291e-04 - val_loss: 2.0948e-04 - 944ms/epoch - 4ms/step
# Epoch 166/250
# 258/258 - 1s - loss: 9.5772e-04 - val_loss: 2.0654e-04 - 974ms/epoch - 4ms/step
# Epoch 167/250
# 258/258 - 1s - loss: 9.5163e-04 - val_loss: 2.0641e-04 - 912ms/epoch - 4ms/step
# Epoch 168/250
# 258/258 - 1s - loss: 9.4170e-04 - val_loss: 2.0579e-04 - 989ms/epoch - 4ms/step
# Epoch 169/250
# 258/258 - 1s - loss: 9.6052e-04 - val_loss: 2.0561e-04 - 899ms/epoch - 3ms/step
# Epoch 170/250
# 258/258 - 1s - loss: 9.5038e-04 - val_loss: 2.0499e-04 - 944ms/epoch - 4ms/step
# Epoch 171/250
# 258/258 - 1s - loss: 9.5043e-04 - val_loss: 2.0204e-04 - 868ms/epoch - 3ms/step
# Epoch 172/250
# 258/258 - 1s - loss: 9.6237e-04 - val_loss: 2.0376e-04 - 866ms/epoch - 3ms/step
# Epoch 173/250
# 258/258 - 1s - loss: 9.5453e-04 - val_loss: 2.0195e-04 - 872ms/epoch - 3ms/step
# Epoch 174/250
# 258/258 - 1s - loss: 9.4528e-04 - val_loss: 2.0459e-04 - 880ms/epoch - 3ms/step
# Epoch 175/250
# 258/258 - 1s - loss: 9.6887e-04 - val_loss: 2.0485e-04 - 865ms/epoch - 3ms/step
# Epoch 176/250
# 258/258 - 1s - loss: 9.3523e-04 - val_loss: 2.0135e-04 - 891ms/epoch - 3ms/step
# Epoch 177/250
# 258/258 - 1s - loss: 9.7528e-04 - val_loss: 2.0211e-04 - 895ms/epoch - 3ms/step
# Epoch 178/250
# 258/258 - 1s - loss: 9.4709e-04 - val_loss: 2.0234e-04 - 896ms/epoch - 3ms/step
# Epoch 179/250
# 258/258 - 1s - loss: 9.4252e-04 - val_loss: 2.0277e-04 - 968ms/epoch - 4ms/step
# Epoch 180/250
# 258/258 - 1s - loss: 9.5053e-04 - val_loss: 2.0279e-04 - 914ms/epoch - 4ms/step
# Epoch 181/250
# 258/258 - 1s - loss: 9.3486e-04 - val_loss: 2.0113e-04 - 914ms/epoch - 4ms/step
# Epoch 182/250
# 258/258 - 1s - loss: 9.4117e-04 - val_loss: 2.0139e-04 - 969ms/epoch - 4ms/step
# Epoch 183/250
# 258/258 - 1s - loss: 9.2581e-04 - val_loss: 2.0191e-04 - 892ms/epoch - 3ms/step
# Epoch 184/250
# 258/258 - 1s - loss: 9.3478e-04 - val_loss: 2.0369e-04 - 897ms/epoch - 3ms/step
# Epoch 185/250
# 258/258 - 1s - loss: 9.1927e-04 - val_loss: 2.0134e-04 - 962ms/epoch - 4ms/step
# Epoch 186/250
# 258/258 - 1s - loss: 9.4040e-04 - val_loss: 2.0030e-04 - 892ms/epoch - 3ms/step
# Epoch 187/250
# 258/258 - 1s - loss: 9.2321e-04 - val_loss: 2.0015e-04 - 898ms/epoch - 3ms/step
# Epoch 188/250
# 258/258 - 1s - loss: 9.3649e-04 - val_loss: 2.0021e-04 - 874ms/epoch - 3ms/step
# Epoch 189/250
# 258/258 - 1s - loss: 9.2474e-04 - val_loss: 2.0087e-04 - 925ms/epoch - 4ms/step
# Epoch 190/250
# 258/258 - 1s - loss: 9.2934e-04 - val_loss: 1.9841e-04 - 882ms/epoch - 3ms/step
# Epoch 191/250
# 258/258 - 1s - loss: 9.4559e-04 - val_loss: 1.9921e-04 - 904ms/epoch - 4ms/step
# Epoch 192/250
# 258/258 - 1s - loss: 9.5736e-04 - val_loss: 1.9751e-04 - 992ms/epoch - 4ms/step
# Epoch 193/250
# 258/258 - 1s - loss: 9.2900e-04 - val_loss: 1.9825e-04 - 1s/epoch - 5ms/step
# Epoch 194/250
# 258/258 - 2s - loss: 9.3652e-04 - val_loss: 1.9809e-04 - 2s/epoch - 6ms/step
# Epoch 195/250
# 258/258 - 2s - loss: 9.2955e-04 - val_loss: 1.9749e-04 - 2s/epoch - 6ms/step
# Epoch 196/250
# 258/258 - 1s - loss: 9.2618e-04 - val_loss: 1.9811e-04 - 1s/epoch - 5ms/step
# Epoch 197/250
# 258/258 - 2s - loss: 9.3569e-04 - val_loss: 1.9721e-04 - 2s/epoch - 6ms/step
# Epoch 198/250
# 258/258 - 1s - loss: 9.2689e-04 - val_loss: 1.9942e-04 - 1s/epoch - 5ms/step
# Epoch 199/250
# 258/258 - 1s - loss: 9.2078e-04 - val_loss: 1.9774e-04 - 959ms/epoch - 4ms/step
# Epoch 200/250
# 258/258 - 1s - loss: 9.2386e-04 - val_loss: 1.9808e-04 - 902ms/epoch - 3ms/step
# Epoch 201/250
# 258/258 - 1s - loss: 9.2201e-04 - val_loss: 1.9799e-04 - 869ms/epoch - 3ms/step
# Epoch 202/250
# 258/258 - 1s - loss: 9.1759e-04 - val_loss: 1.9514e-04 - 971ms/epoch - 4ms/step
# Epoch 203/250
# 258/258 - 1s - loss: 9.2776e-04 - val_loss: 1.9644e-04 - 877ms/epoch - 3ms/step
# Epoch 204/250
# 258/258 - 1s - loss: 9.2741e-04 - val_loss: 1.9456e-04 - 962ms/epoch - 4ms/step
# Epoch 205/250
# 258/258 - 1s - loss: 9.2804e-04 - val_loss: 1.9796e-04 - 881ms/epoch - 3ms/step
# Epoch 206/250
# 258/258 - 1s - loss: 9.3965e-04 - val_loss: 1.9427e-04 - 872ms/epoch - 3ms/step
# Epoch 207/250
# 258/258 - 1s - loss: 9.2440e-04 - val_loss: 1.9373e-04 - 890ms/epoch - 3ms/step
# Epoch 208/250
# 258/258 - 1s - loss: 9.3716e-04 - val_loss: 1.9663e-04 - 950ms/epoch - 4ms/step
# Epoch 209/250
# 258/258 - 1s - loss: 9.1172e-04 - val_loss: 1.9752e-04 - 872ms/epoch - 3ms/step
# Epoch 210/250
# 258/258 - 1s - loss: 9.2022e-04 - val_loss: 1.9782e-04 - 1s/epoch - 4ms/step
# Epoch 211/250
# 258/258 - 1s - loss: 9.1583e-04 - val_loss: 1.9235e-04 - 880ms/epoch - 3ms/step
# Epoch 212/250
# 258/258 - 1s - loss: 8.8659e-04 - val_loss: 1.9252e-04 - 939ms/epoch - 4ms/step
# Epoch 213/250
# 258/258 - 1s - loss: 9.2697e-04 - val_loss: 1.9504e-04 - 890ms/epoch - 3ms/step
# Epoch 214/250
# 258/258 - 1s - loss: 9.4199e-04 - val_loss: 1.9352e-04 - 875ms/epoch - 3ms/step
# Epoch 215/250
# 258/258 - 1s - loss: 9.0856e-04 - val_loss: 1.9067e-04 - 882ms/epoch - 3ms/step
# Epoch 216/250
# 258/258 - 1s - loss: 9.3092e-04 - val_loss: 1.9053e-04 - 881ms/epoch - 3ms/step
# Epoch 217/250
# 258/258 - 1s - loss: 9.3979e-04 - val_loss: 1.9312e-04 - 879ms/epoch - 3ms/step
# Epoch 218/250
# 258/258 - 1s - loss: 9.3470e-04 - val_loss: 1.9115e-04 - 888ms/epoch - 3ms/step
# Epoch 219/250
# 258/258 - 1s - loss: 9.0608e-04 - val_loss: 1.8991e-04 - 954ms/epoch - 4ms/step
# Epoch 220/250
# 258/258 - 1s - loss: 9.1685e-04 - val_loss: 1.9310e-04 - 883ms/epoch - 3ms/step
# Epoch 221/250
# 258/258 - 1s - loss: 9.1524e-04 - val_loss: 1.9484e-04 - 951ms/epoch - 4ms/step
# Epoch 222/250
# 258/258 - 1s - loss: 9.2504e-04 - val_loss: 1.9044e-04 - 903ms/epoch - 4ms/step
# Epoch 223/250
# 258/258 - 1s - loss: 9.1127e-04 - val_loss: 1.9082e-04 - 899ms/epoch - 3ms/step
# Epoch 224/250
# 258/258 - 1s - loss: 8.9343e-04 - val_loss: 1.9054e-04 - 877ms/epoch - 3ms/step
# Epoch 225/250
# 258/258 - 1s - loss: 9.0979e-04 - val_loss: 1.8934e-04 - 1s/epoch - 4ms/step
# Epoch 226/250
# 258/258 - 1s - loss: 8.9791e-04 - val_loss: 1.9228e-04 - 1s/epoch - 5ms/step
# Epoch 227/250
# 258/258 - 2s - loss: 8.9947e-04 - val_loss: 1.8968e-04 - 2s/epoch - 6ms/step
# Epoch 228/250
# 258/258 - 2s - loss: 9.0707e-04 - val_loss: 1.9336e-04 - 2s/epoch - 6ms/step
# Epoch 229/250
# 258/258 - 1s - loss: 9.1161e-04 - val_loss: 1.8983e-04 - 1s/epoch - 6ms/step
# Epoch 230/250
# 258/258 - 1s - loss: 9.0556e-04 - val_loss: 1.8931e-04 - 1s/epoch - 5ms/step
# Epoch 231/250
# 258/258 - 2s - loss: 9.0835e-04 - val_loss: 1.8776e-04 - 2s/epoch - 6ms/step
# Epoch 232/250
# 258/258 - 1s - loss: 8.9668e-04 - val_loss: 1.8690e-04 - 886ms/epoch - 3ms/step
# Epoch 233/250
# 258/258 - 1s - loss: 8.9381e-04 - val_loss: 1.8901e-04 - 892ms/epoch - 3ms/step
# Epoch 234/250
# 258/258 - 1s - loss: 8.9635e-04 - val_loss: 1.8889e-04 - 882ms/epoch - 3ms/step
# Epoch 235/250
# 258/258 - 1s - loss: 9.1587e-04 - val_loss: 1.8754e-04 - 874ms/epoch - 3ms/step
# Epoch 236/250
# 258/258 - 1s - loss: 9.0037e-04 - val_loss: 1.8921e-04 - 968ms/epoch - 4ms/step

# %%
final_list= [] 
list_of_ops=[] 
list_of_units=[] 
list_of_loss=[] 
vali_list=[] 
test_list=[] 
# 'units':units,'optimizer':optmzr,'Loss':loss_tmp,'ValRMSE':validation_rmse,'TestRMSE':test_rmse

for result in list_of_results:
  list_of_units.append(result['units']) 
  list_of_ops.append(result['optimizer']) 
  list_of_loss.append(result['Loss']) 
  vali_list.append(result['ValRMSE']) 
  test_list.append(result['TestRMSE']) 
# final_list.append(list_of_ops)
# final_list.append(list_of_ops)
final_list=[list_of_units,list_of_ops,list_of_loss,vali_list,test_list]  
# final_list
print(final_list)
